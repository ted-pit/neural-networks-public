# %%
# !pip install dmol-book
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dmol-book
#   Downloading dmol_book-1.3.2-py3-none-any.whl (2.4 kB)
# Collecting e3nn
#   Downloading e3nn-0.5.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 6.9 MB/s eta 0:00:00
# Collecting simpletransformers==0.63.9
#   Downloading simpletransformers-0.63.9-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 KB 6.5 MB/s eta 0:00:00
# Collecting torch==1.12
#   Downloading torch-1.12.0-cp39-cp39-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 1.7 MB/s eta 0:00:00
# Collecting MDAnalysis
#   Downloading MDAnalysis-2.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.9/dist-packages (from dmol-book) (0.4.7+cuda11.cudnn86)
# Collecting mordred[full]
#   Downloading mordred-1.2.0.tar.gz (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 KB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jupyter-book==0.13.1
#   Downloading jupyter_book-0.13.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 KB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from dmol-book) (3.7.1)
# Collecting exmol
#   Downloading exmol-3.0.2-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from dmol-book) (1.4.4)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.9/dist-packages (from dmol-book) (1.0.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from dmol-book) (3.0)
# Requirement already satisfied: tensorflow>=2.7 in /usr/local/lib/python3.9/dist-packages (from dmol-book) (2.12.0)
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 KB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from dmol-book) (1.11.1)
# Collecting rdkit>=2022
#   Downloading rdkit-2022.9.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from dmol-book) (0.12.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from dmol-book) (0.8.10)
# Collecting emlp==1.0.2
#   Downloading emlp-1.0.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 KB 4.7 MB/s eta 0:00:00
# Collecting linkify-it-py
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.9/dist-packages (from dmol-book) (0.19.0)
# Collecting dm-haiku
#   Downloading dm_haiku-0.0.9-py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 25.4 MB/s eta 0:00:00
# Collecting selfies
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: ipython!=8.7.0jax in /usr/local/lib/python3.9/dist-packages (from dmol-book) (7.34.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from dmol-book) (1.2.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.9/dist-packages (from dmol-book) (8.4.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.9/dist-packages (from dmol-book) (1.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from dmol-book) (1.22.4)
# Collecting objax
#   Downloading objax-1.6.0.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 KB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from emlp==1.0.2->dmol-book) (3.8.0)
# Collecting plum-dispatch
#   Downloading plum_dispatch-2.0.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from emlp==1.0.2->dmol-book) (7.2.2)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import sklearn
from sklearn import metrics
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

##acquire data
data = pd.read_csv(
    "gdrive/MyDrive/dataset/CSD_EES_DB.csv"
)
data.head()
# Out:
# Mounted at /content/gdrive
#          ID                        doi            formula  NAts  \
# 0  AACFAZ10  10.1107/S0108270183005156  C26 H22 Cl2 N2 O6  36.0
# 1    ABACIR  10.1107/S160053681103861X   C17 H21 N3 O4 S2  26.0
# 2    ABADEO  10.1107/S1600536811039158      C30 H28 N6 O2  38.0
# 3    ABADUE  10.1107/S1600536811039110      C17 H17 N1 O4  22.0
# 4    ABAGAN  10.1107/S1600536811038177      C26 H17 O1 P1  28.0
#
#                                               SMILES      HOMO      LUMO  \
# 0  COC1=C(C(OC1=O)c1ccccc1Cl)C(C)=NN=C(C)C1=C(OC)... -7.548438 -1.912144
# 1     O=N(=O)c1ccccc1NCC1=CSC(=C1)S(=O)(=O)NC1CCCCC1 -7.675787 -1.725202
# 2  CN1N(c2ccccc2)C(=O)C(=C1C)N=Cc1ccccc1C=NC1=C(C... -6.603659 -0.762191
# 3               COc1cc(OC)c(C=CC(=O)c2ccccn2)c(OC)c1 -6.790057 -0.969814
# 4        O=P1(c2ccccc2)c2ccc3ccccc3c2c2c3ccccc3ccc12 -7.067613 -1.419890
#
#     E(S1)   f(S1)   E(S2)   f(S2)   E(S3)   f(S3)   E(T1)   E(T2)   E(T3)
# 0  3.1382  0.0027  3.8297  1.1448  4.5310  0.0000  2.2270  2.8977  3.0885
# 1  3.6720  0.0982  3.7456  0.0888  4.1316  0.0016  2.3255  2.8794  3.2735
# 2  3.9027  0.7900  4.0170  0.2765  4.1450  0.0455  2.6892  3.0039  3.5964
# 3  3.3127  0.0001  3.9203  0.7088  4.6824  0.0265  2.5848  2.9294  3.9060
# 4  3.6197  0.1814  4.2742  0.0073  4.4154  0.0007  2.5192  3.2095  3.8388

# %%
train_proportion = 0.9
train_data = data[:int(0.9*len(data))]
test_data = data[int(0.9*len(data)):]

features_start_at = list(train_data.columns).index("LUMO")
feature_names = train_data.columns[ features_start_at:]
f = train_data.loc[:, feature_names].values
fmean = np.mean(f, axis=0)
fstd = np.std(f, axis=0)
features = ((f - fmean) / fstd)

g = test_data.loc[:, feature_names].values
gmean = np.mean(g, axis=0)
gstd = np.std(g, axis=0)
test_features = ((g - gmean) / gstd)

labels = train_data.HOMO.values
test_labels = test_data.HOMO.values

train = tf.data.Dataset.from_tensor_slices( (features, labels))
test = tf.data.Dataset.from_tensor_slices( (test_features, test_labels))

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(16, activation="tanh"))
model.add(tf.keras.layers.Dense(28, activation="tanh"))
model.add(tf.keras.layers.Dense(16, activation="tanh"))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer="SGD", loss="mean_absolute_error")

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer="SGD", loss="mean_absolute_error")

# %%
model.fit(features, labels, epochs=50, validation_split=0.03)
# Out:
# Epoch 1/50
# 1315/1315 [==============================] - 4s 3ms/step - loss: 0.5857 - val_loss: 0.2625
# Epoch 2/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.2454 - val_loss: 0.2493
# Epoch 3/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2347 - val_loss: 0.2263
# Epoch 4/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2289 - val_loss: 0.2202
# Epoch 5/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2223 - val_loss: 0.2288
# Epoch 6/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2194 - val_loss: 0.2072
# Epoch 7/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.2160 - val_loss: 0.2181
# Epoch 8/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2139 - val_loss: 0.2613
# Epoch 9/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2113 - val_loss: 0.2001
# Epoch 10/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2090 - val_loss: 0.2035
# Epoch 11/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2083 - val_loss: 0.2115
# Epoch 12/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.2060 - val_loss: 0.2004
# Epoch 13/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.2043 - val_loss: 0.2016
# Epoch 14/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2039 - val_loss: 0.1983
# Epoch 15/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2024 - val_loss: 0.1957
# Epoch 16/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2017 - val_loss: 0.2048
# Epoch 17/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.2008 - val_loss: 0.1920
# Epoch 18/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.2016 - val_loss: 0.2411
# Epoch 19/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.2000 - val_loss: 0.1905
# Epoch 20/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1987 - val_loss: 0.1936
# Epoch 21/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1982 - val_loss: 0.2078
# Epoch 22/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1974 - val_loss: 0.2258
# Epoch 23/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1975 - val_loss: 0.1930
# Epoch 24/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1965 - val_loss: 0.2016
# Epoch 25/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1958 - val_loss: 0.1922
# Epoch 26/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1959 - val_loss: 0.1938
# Epoch 27/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1948 - val_loss: 0.1862
# Epoch 28/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1947 - val_loss: 0.1931
# Epoch 29/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1938 - val_loss: 0.1864
# Epoch 30/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1928 - val_loss: 0.1879
# Epoch 31/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1928 - val_loss: 0.1922
# Epoch 32/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1917 - val_loss: 0.2218
# Epoch 33/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1914 - val_loss: 0.1893
# Epoch 34/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1919 - val_loss: 0.2288
# Epoch 35/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1906 - val_loss: 0.1829
# Epoch 36/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1904 - val_loss: 0.1984
# Epoch 37/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1903 - val_loss: 0.1820
# Epoch 38/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1903 - val_loss: 0.2115
# Epoch 39/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1905 - val_loss: 0.1812
# Epoch 40/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1893 - val_loss: 0.2004
# Epoch 41/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1888 - val_loss: 0.1837
# Epoch 42/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1882 - val_loss: 0.1832
# Epoch 43/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1879 - val_loss: 0.2057
# Epoch 44/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1872 - val_loss: 0.1990
# Epoch 45/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1881 - val_loss: 0.1857
# Epoch 46/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1868 - val_loss: 0.1826
# Epoch 47/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1870 - val_loss: 0.1866
# Epoch 48/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1864 - val_loss: 0.1806
# Epoch 49/50
# 1315/1315 [==============================] - 3s 2ms/step - loss: 0.1866 - val_loss: 0.1835
# Epoch 50/50
# 1315/1315 [==============================] - 2s 2ms/step - loss: 0.1863 - val_loss: 0.1835

# %%
test_predicted_labels = model.predict(test_features)
train_predicted_labels = model(features)

test_metrics = "test\nR2  " + str(sklearn.metrics.r2_score(test_labels, test_predicted_labels))+"\nMAE  "+ str(sklearn.metrics.mean_absolute_error(test_labels, test_predicted_labels))+"\nRMSE  "+ str(sklearn.metrics.mean_squared_error(test_labels, test_predicted_labels, squared=False))
train_metrics = "train\nR2  " + str(sklearn.metrics.r2_score(labels, train_predicted_labels))+"\nMAE  "+ str(sklearn.metrics.mean_absolute_error(labels, train_predicted_labels))+"\nRMSE  "+ str(sklearn.metrics.mean_squared_error(labels, train_predicted_labels, squared=False))
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(labels, train_predicted_labels, c='Blue', label=train_metrics, alpha=0.4, marker='^')
ax1.scatter(test_labels, test_predicted_labels, c='Red', label=test_metrics, alpha=0.5, marker='8')
plt.legend(loc='upper left')
ax1.set_xlabel("HOMO /eV  (true)")
ax1.set_ylabel("HOMO /eV  (predicted)")
ax1.plot([0,1],[0,1], transform=ax1.transAxes, c='Black', alpha=0.5)
fig.set_figwidth(8)
fig.set_figheight(6)
# Out:
# 151/151 [==============================] - 0s 2ms/step
